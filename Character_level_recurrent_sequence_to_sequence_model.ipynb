# %% [markdown]
# # Character-level recurrent sequence-to-sequence model
#
# Reference:
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2017/09/29<br>
# **Last modified:** 2020/04/26<br>
# **Description:** Character-level recurrent sequence-to-sequence model.

# %% [markdown]
# [Dataset source](http://www.manythings.org/anki/)

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to implement a basic character-level
# recurrent sequence-to-sequence model. We apply it to translating
# short English sentences into short French sentences,
# character-by-character. Note that it is fairly unusual to
# do character-level machine translation, as word-level
# models are more common in this domain.
#
# **Summary of the algorithm**
#
# - We start with input sequences from a domain (e.g. English sentences)
#     and corresponding target sequences from another domain
#     (e.g. French sentences).
# - An encoder LSTM turns input sequences to 2 state vectors
#     (we keep the last LSTM state and discard the outputs).
# - A decoder LSTM is trained to turn the target sequences into
#     the same sequence but offset by one timestep in the future,
#     a training process called "teacher forcing" in this context.
#     It uses as initial state the state vectors from the encoder.
#     Effectively, the decoder learns to generate `targets[t+1...]`
#     given `targets[...t]`, conditioned on the input sequence.
# - In inference mode, when we want to decode unknown input sequences, we:
#     - Encode the input sequence into state vectors
#     - Start with a target sequence of size 1
#         (just the start-of-sequence character)
#     - Feed the state vectors and 1-char target sequence
#         to the decoder to produce predictions for the next character
#     - Sample the next character using these predictions
#         (we simply use argmax).
#     - Append the sampled character to the target sequence
#     - Repeat until we generate the end-of-sequence character or we
#         hit the character limit.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Download the data

# %%
# !!curl -O http://www.manythings.org/anki/fra-eng.zip
# !!unzip fra-eng.zip
# Out:
# ['Archive:  fra-eng.zip',
#  '  inflating: _about.txt              ',
#  '  inflating: fra.txt                 ']

# %% [markdown]
# ## Configuration

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = "fra.txt"

# %% [markdown]
# ## Prepare the data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

# %%
print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 71
# Number of unique output tokens: 93
# Max sequence length for inputs: 15
# Max sequence length for outputs: 59

# %% [markdown]
# ###Input Tokens

# %%
input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

# %%
target_token_index

# %% [markdown]
# ###Encoder and Decoder

# %%
# refer to blog for more on the parameters: https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

# %% [markdown]
# ###One-Hot Representation

# %%
#You can simply use the keras One-hot encoder to do same thing: https://machinelearningmastery.com/how-to-one-hot-encode-sequence-data-in-python/

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0

# %% [markdown]
# ## Build the model

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens)) #encoder input shape
encoder = keras.layers.LSTM(latent_dim, return_state=True) #specify the latent_dim(your timestamp)
encoder_outputs, state_h, state_c = encoder(encoder_inputs) #encoder returns encoder output, hidden state and cell state

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c] #only keep the hidden state and cell state


# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)

decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax") #adding dense layer
decoder_outputs = decoder_dense(decoder_outputs) #getting all the output

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# ## Train the model

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 51s 384ms/step - loss: 1.1448 - accuracy: 0.7310 - val_loss: 1.0205 - val_accuracy: 0.7166
# Epoch 2/100
# 125/125 [==============================] - 47s 379ms/step - loss: 0.8323 - accuracy: 0.7762 - val_loss: 0.8413 - val_accuracy: 0.7679
# Epoch 3/100
# 125/125 [==============================] - 48s 381ms/step - loss: 0.6694 - accuracy: 0.8139 - val_loss: 0.7072 - val_accuracy: 0.7956
# Epoch 4/100
# 125/125 [==============================] - 48s 381ms/step - loss: 0.5768 - accuracy: 0.8329 - val_loss: 0.6389 - val_accuracy: 0.8134
# Epoch 5/100
# 125/125 [==============================] - 48s 384ms/step - loss: 0.5265 - accuracy: 0.8460 - val_loss: 0.5963 - val_accuracy: 0.8281
# Epoch 6/100
# 125/125 [==============================] - 48s 383ms/step - loss: 0.4904 - accuracy: 0.8558 - val_loss: 0.5612 - val_accuracy: 0.8363
# Epoch 7/100
# 125/125 [==============================] - 48s 388ms/step - loss: 0.4619 - accuracy: 0.8634 - val_loss: 0.5360 - val_accuracy: 0.8438
# Epoch 8/100
# 125/125 [==============================] - 48s 387ms/step - loss: 0.4385 - accuracy: 0.8695 - val_loss: 0.5184 - val_accuracy: 0.8474
# Epoch 9/100
# 125/125 [==============================] - 48s 385ms/step - loss: 0.4182 - accuracy: 0.8752 - val_loss: 0.5091 - val_accuracy: 0.8504
# Epoch 10/100
# 125/125 [==============================] - 48s 383ms/step - loss: 0.3996 - accuracy: 0.8803 - val_loss: 0.4916 - val_accuracy: 0.8551
# Epoch 11/100
# 125/125 [==============================] - 48s 383ms/step - loss: 0.3827 - accuracy: 0.8851 - val_loss: 0.4785 - val_accuracy: 0.8585
# Epoch 12/100
# 125/125 [==============================] - 48s 386ms/step - loss: 0.3674 - accuracy: 0.8893 - val_loss: 0.4747 - val_accuracy: 0.8605
# Epoch 13/100
# 125/125 [==============================] - 49s 388ms/step - loss: 0.3529 - accuracy: 0.8937 - val_loss: 0.4635 - val_accuracy: 0.8633
# Epoch 14/100
# 125/125 [==============================] - 48s 387ms/step - loss: 0.3398 - accuracy: 0.8972 - val_loss: 0.4632 - val_accuracy: 0.8629
# Epoch 15/100
# 125/125 [==============================] - 48s 381ms/step - loss: 0.3272 - accuracy: 0.9016 - val_loss: 0.4528 - val_accuracy: 0.8677
# Epoch 16/100
# 125/125 [==============================] - 47s 380ms/step - loss: 0.3154 - accuracy: 0.9049 - val_loss: 0.4505 - val_accuracy: 0.8689
# Epoch 17/100
# 125/125 [==============================] - 48s 383ms/step - loss: 0.3041 - accuracy: 0.9079 - val_loss: 0.4468 - val_accuracy: 0.8705
# Epoch 18/100
# 125/125 [==============================] - 47s 380ms/step - loss: 0.2937 - accuracy: 0.9112 - val_loss: 0.4438 - val_accuracy: 0.8715
# Epoch 19/100
# 125/125 [==============================] - 47s 380ms/step - loss: 0.2831 - accuracy: 0.9142 - val_loss: 0.4427 - val_accuracy: 0.8722
# Epoch 20/100
# 125/125 [==============================] - 47s 379ms/step - loss: 0.2735 - accuracy: 0.9175 - val_loss: 0.4435 - val_accuracy: 0.8721
# Epoch 21/100
# 125/125 [==============================] - 47s 375ms/step - loss: 0.2643 - accuracy: 0.9203 - val_loss: 0.4390 - val_accuracy: 0.8751
# Epoch 22/100
# 125/125 [==============================] - 47s 376ms/step - loss: 0.2556 - accuracy: 0.9223 - val_loss: 0.4412 - val_accuracy: 0.8751
# Epoch 23/100
# 125/125 [==============================] - 47s 377ms/step - loss: 0.2470 - accuracy: 0.9249 - val_loss: 0.4417 - val_accuracy: 0.8760
# Epoch 24/100
# 125/125 [==============================] - 47s 378ms/step - loss: 0.2388 - accuracy: 0.9275 - val_loss: 0.4434 - val_accuracy: 0.8753
# Epoch 25/100
# 125/125 [==============================] - 47s 380ms/step - loss: 0.2313 - accuracy: 0.9298 - val_loss: 0.4437 - val_accuracy: 0.8755
# Epoch 26/100
# 125/125 [==============================] - 47s 378ms/step - loss: 0.2234 - accuracy: 0.9322 - val_loss: 0.4487 - val_accuracy: 0.8758
# Epoch 27/100
# 125/125 [==============================] - 47s 379ms/step - loss: 0.2169 - accuracy: 0.9342 - val_loss: 0.4469 - val_accuracy: 0.8770
# Epoch 28/100
# 125/125 [==============================] - 47s 377ms/step - loss: 0.2099 - accuracy: 0.9362 - val_loss: 0.4476 - val_accuracy: 0.8757
# Epoch 29/100
# 125/125 [==============================] - 47s 377ms/step - loss: 0.2033 - accuracy: 0.9382 - val_loss: 0.4535 - val_accuracy: 0.8768
# Epoch 30/100
# 125/125 [==============================] - 48s 383ms/step - loss: 0.1967 - accuracy: 0.9402 - val_loss: 0.4598 - val_accuracy: 0.8761
# Epoch 31/100
# 125/125 [==============================] - 48s 381ms/step - loss: 0.1909 - accuracy: 0.9417 - val_loss: 0.4629 - val_accuracy: 0.8765
# Epoch 32/100
# 125/125 [==============================] - 47s 379ms/step - loss: 0.1851 - accuracy: 0.9436 - val_loss: 0.4689 - val_accuracy: 0.8750
# Epoch 33/100
# 125/125 [==============================] - 47s 380ms/step - loss: 0.1795 - accuracy: 0.9451 - val_loss: 0.4717 - val_accuracy: 0.8761
# Epoch 34/100
# 125/125 [==============================] - 48s 382ms/step - loss: 0.1736 - accuracy: 0.9472 - val_loss: 0.4724 - val_accuracy: 0.8762
# Epoch 35/100
# 125/125 [==============================] - 48s 383ms/step - loss: 0.1693 - accuracy: 0.9483 - val_loss: 0.4816 - val_accuracy: 0.8756
# Epoch 36/100
# 125/125 [==============================] - 47s 379ms/step - loss: 0.1641 - accuracy: 0.9498 - val_loss: 0.4820 - val_accuracy: 0.8770
# Epoch 37/100
# 125/125 [==============================] - 47s 379ms/step - loss: 0.1597 - accuracy: 0.9511 - val_loss: 0.4898 - val_accuracy: 0.8760
# Epoch 38/100
# 125/125 [==============================] - 47s 378ms/step - loss: 0.1547 - accuracy: 0.9527 - val_loss: 0.4895 - val_accuracy: 0.8764
# Epoch 39/100
# 125/125 [==============================] - 47s 378ms/step - loss: 0.1503 - accuracy: 0.9538 - val_loss: 0.4969 - val_accuracy: 0.8752
# Epoch 40/100
# 125/125 [==============================] - 47s 380ms/step - loss: 0.1461 - accuracy: 0.9549 - val_loss: 0.4994 - val_accuracy: 0.8759
# Epoch 41/100
# 125/125 [==============================] - 48s 381ms/step - loss: 0.1422 - accuracy: 0.9564 - val_loss: 0.5034 - val_accuracy: 0.8763
# Epoch 42/100
# 125/125 [==============================] - 47s 380ms/step - loss: 0.1389 - accuracy: 0.9571 - val_loss: 0.5073 - val_accuracy: 0.8758
# Epoch 43/100
# 125/125 [==============================] - 47s 375ms/step - loss: 0.1347 - accuracy: 0.9586 - val_loss: 0.5198 - val_accuracy: 0.8744
# Epoch 44/100
# 125/125 [==============================] - 47s 374ms/step - loss: 0.1315 - accuracy: 0.9594 - val_loss: 0.5213 - val_accuracy: 0.8756
# Epoch 45/100
# 125/125 [==============================] - 47s 374ms/step - loss: 0.1276 - accuracy: 0.9605 - val_loss: 0.5203 - val_accuracy: 0.8756
# Epoch 46/100
# 125/125 [==============================] - 47s 373ms/step - loss: 0.1245 - accuracy: 0.9615 - val_loss: 0.5353 - val_accuracy: 0.8748
# Epoch 47/100
# 125/125 [==============================] - 50s 399ms/step - loss: 0.1215 - accuracy: 0.9623 - val_loss: 0.5351 - val_accuracy: 0.8757
# Epoch 48/100
# 125/125 [==============================] - 49s 395ms/step - loss: 0.1185 - accuracy: 0.9630 - val_loss: 0.5428 - val_accuracy: 0.8754
# Epoch 49/100
# 125/125 [==============================] - 48s 382ms/step - loss: 0.1155 - accuracy: 0.9642 - val_loss: 0.5431 - val_accuracy: 0.8751
# Epoch 50/100
# 125/125 [==============================] - 47s 379ms/step - loss: 0.1128 - accuracy: 0.9648 - val_loss: 0.5476 - val_accuracy: 0.8755
# Epoch 51/100
# 125/125 [==============================] - 48s 384ms/step - loss: 0.1099 - accuracy: 0.9657 - val_loss: 0.5555 - val_accuracy: 0.8737
# Epoch 52/100
# 125/125 [==============================] - 51s 407ms/step - loss: 0.1073 - accuracy: 0.9663 - val_loss: 0.5618 - val_accuracy: 0.8746
# Epoch 53/100
# 125/125 [==============================] - 51s 407ms/step - loss: 0.1047 - accuracy: 0.9670 - val_loss: 0.5687 - val_accuracy: 0.8751
# Epoch 54/100
# 125/125 [==============================] - 50s 402ms/step - loss: 0.1024 - accuracy: 0.9677 - val_loss: 0.5673 - val_accuracy: 0.8752
# Epoch 55/100
# 125/125 [==============================] - 50s 398ms/step - loss: 0.1001 - accuracy: 0.9684 - val_loss: 0.5686 - val_accuracy: 0.8746
# Epoch 56/100
# 125/125 [==============================] - 49s 390ms/step - loss: 0.0980 - accuracy: 0.9691 - val_loss: 0.5783 - val_accuracy: 0.8746
# Epoch 57/100
# 125/125 [==============================] - 51s 406ms/step - loss: 0.0960 - accuracy: 0.9697 - val_loss: 0.5827 - val_accuracy: 0.8750
# Epoch 58/100
# 125/125 [==============================] - 49s 395ms/step - loss: 0.0937 - accuracy: 0.9702 - val_loss: 0.5860 - val_accuracy: 0.8746
# Epoch 59/100
# 125/125 [==============================] - 50s 398ms/step - loss: 0.0920 - accuracy: 0.9707 - val_loss: 0.5911 - val_accuracy: 0.8740
# Epoch 60/100
# 125/125 [==============================] - 48s 384ms/step - loss: 0.0895 - accuracy: 0.9715 - val_loss: 0.5987 - val_accuracy: 0.8738
# Epoch 61/100
# 125/125 [==============================] - 48s 385ms/step - loss: 0.0879 - accuracy: 0.9720 - val_loss: 0.6027 - val_accuracy: 0.8749
# Epoch 62/100
# 125/125 [==============================] - 48s 383ms/step - loss: 0.0860 - accuracy: 0.9725 - val_loss: 0.6017 - val_accuracy: 0.8732
# Epoch 63/100
# 125/125 [==============================] - 48s 381ms/step - loss: 0.0842 - accuracy: 0.9731 - val_loss: 0.6125 - val_accuracy: 0.8737
# Epoch 64/100
# 125/125 [==============================] - 47s 380ms/step - loss: 0.0831 - accuracy: 0.9732 - val_loss: 0.6189 - val_accuracy: 0.8736
# Epoch 65/100
# 125/125 [==============================] - 48s 382ms/step - loss: 0.0808 - accuracy: 0.9738 - val_loss: 0.6228 - val_accuracy: 0.8727
# Epoch 66/100
# 125/125 [==============================] - 48s 381ms/step - loss: 0.0796 - accuracy: 0.9743 - val_loss: 0.6261 - val_accuracy: 0.8732
# Epoch 67/100
# 125/125 [==============================] - 48s 385ms/step - loss: 0.0778 - accuracy: 0.9747 - val_loss: 0.6269 - val_accuracy: 0.8730
# Epoch 68/100
# 125/125 [==============================] - 48s 386ms/step - loss: 0.0763 - accuracy: 0.9753 - val_loss: 0.6323 - val_accuracy: 0.8730
# Epoch 69/100
# 125/125 [==============================] - 48s 386ms/step - loss: 0.0749 - accuracy: 0.9756 - val_loss: 0.6351 - val_accuracy: 0.8746
# Epoch 70/100
# 125/125 [==============================] - 48s 387ms/step - loss: 0.0734 - accuracy: 0.9761 - val_loss: 0.6443 - val_accuracy: 0.8729
# Epoch 71/100
# 125/125 [==============================] - 49s 390ms/step - loss: 0.0719 - accuracy: 0.9765 - val_loss: 0.6438 - val_accuracy: 0.8728
# Epoch 72/100
# 125/125 [==============================] - 54s 433ms/step - loss: 0.0708 - accuracy: 0.9769 - val_loss: 0.6465 - val_accuracy: 0.8738
# Epoch 73/100
# 125/125 [==============================] - 55s 438ms/step - loss: 0.0695 - accuracy: 0.9772 - val_loss: 0.6533 - val_accuracy: 0.8733
# Epoch 74/100
# 125/125 [==============================] - 55s 442ms/step - loss: 0.0680 - accuracy: 0.9777 - val_loss: 0.6538 - val_accuracy: 0.8729
# Epoch 75/100
# 125/125 [==============================] - 52s 414ms/step - loss: 0.0671 - accuracy: 0.9779 - val_loss: 0.6576 - val_accuracy: 0.8735
# Epoch 76/100
# 125/125 [==============================] - 51s 406ms/step - loss: 0.0659 - accuracy: 0.9779 - val_loss: 0.6632 - val_accuracy: 0.8726
# Epoch 77/100
# 125/125 [==============================] - 51s 408ms/step - loss: 0.0645 - accuracy: 0.9783 - val_loss: 0.6687 - val_accuracy: 0.8729
# Epoch 78/100
# 125/125 [==============================] - 52s 413ms/step - loss: 0.0637 - accuracy: 0.9789 - val_loss: 0.6692 - val_accuracy: 0.8733
# Epoch 79/100
# 125/125 [==============================] - 51s 412ms/step - loss: 0.0627 - accuracy: 0.9790 - val_loss: 0.6725 - val_accuracy: 0.8726
# Epoch 80/100
# 125/125 [==============================] - 51s 410ms/step - loss: 0.0617 - accuracy: 0.9792 - val_loss: 0.6748 - val_accuracy: 0.8717
# Epoch 81/100
# 125/125 [==============================] - 52s 414ms/step - loss: 0.0607 - accuracy: 0.9795 - val_loss: 0.6782 - val_accuracy: 0.8726
# Epoch 82/100
# 125/125 [==============================] - 51s 412ms/step - loss: 0.0594 - accuracy: 0.9800 - val_loss: 0.6907 - val_accuracy: 0.8727
# Epoch 83/100
# 125/125 [==============================] - 50s 403ms/step - loss: 0.0586 - accuracy: 0.9800 - val_loss: 0.6888 - val_accuracy: 0.8724
# Epoch 84/100
# 125/125 [==============================] - 50s 398ms/step - loss: 0.0576 - accuracy: 0.9804 - val_loss: 0.6943 - val_accuracy: 0.8723
# Epoch 85/100
# 125/125 [==============================] - 49s 389ms/step - loss: 0.0564 - accuracy: 0.9808 - val_loss: 0.7038 - val_accuracy: 0.8709
# Epoch 86/100
# 125/125 [==============================] - 49s 388ms/step - loss: 0.0558 - accuracy: 0.9811 - val_loss: 0.7068 - val_accuracy: 0.8728
# Epoch 87/100
# 125/125 [==============================] - 49s 395ms/step - loss: 0.0551 - accuracy: 0.9811 - val_loss: 0.7071 - val_accuracy: 0.8721
# Epoch 88/100
# 125/125 [==============================] - 48s 385ms/step - loss: 0.0538 - accuracy: 0.9814 - val_loss: 0.7076 - val_accuracy: 0.8711
# Epoch 89/100
# 125/125 [==============================] - 49s 389ms/step - loss: 0.0533 - accuracy: 0.9816 - val_loss: 0.7091 - val_accuracy: 0.8725
# Epoch 90/100
# 125/125 [==============================] - 48s 385ms/step - loss: 0.0523 - accuracy: 0.9821 - val_loss: 0.7184 - val_accuracy: 0.8725
# Epoch 91/100
# 125/125 [==============================] - 48s 385ms/step - loss: 0.0519 - accuracy: 0.9822 - val_loss: 0.7183 - val_accuracy: 0.8720
# Epoch 92/100
# 125/125 [==============================] - 48s 383ms/step - loss: 0.0513 - accuracy: 0.9822 - val_loss: 0.7220 - val_accuracy: 0.8717
# Epoch 93/100
# 125/125 [==============================] - 48s 384ms/step - loss: 0.0506 - accuracy: 0.9823 - val_loss: 0.7251 - val_accuracy: 0.8720
# Epoch 94/100
# 125/125 [==============================] - 52s 420ms/step - loss: 0.0498 - accuracy: 0.9826 - val_loss: 0.7284 - val_accuracy: 0.8717
# Epoch 95/100
# 125/125 [==============================] - 52s 420ms/step - loss: 0.0493 - accuracy: 0.9827 - val_loss: 0.7316 - val_accuracy: 0.8711
# Epoch 96/100
# 125/125 [==============================] - 54s 434ms/step - loss: 0.0484 - accuracy: 0.9830 - val_loss: 0.7336 - val_accuracy: 0.8715
# Epoch 97/100
# 125/125 [==============================] - 50s 399ms/step - loss: 0.0480 - accuracy: 0.9833 - val_loss: 0.7369 - val_accuracy: 0.8721
# Epoch 98/100
# 125/125 [==============================] - 50s 402ms/step - loss: 0.0474 - accuracy: 0.9831 - val_loss: 0.7373 - val_accuracy: 0.8716
# Epoch 99/100
# 125/125 [==============================] - 51s 408ms/step - loss: 0.0470 - accuracy: 0.9834 - val_loss: 0.7374 - val_accuracy: 0.8722
# Epoch 100/100
# 125/125 [==============================] - 51s 406ms/step - loss: 0.0463 - accuracy: 0.9835 - val_loss: 0.7464 - val_accuracy: 0.8724
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: s2s/assets
# INFO:tensorflow:Assets written to: s2s/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7c5d107a10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7c5d169110> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# #Student Assignment
#
# Review the following code and provide your understanding of each line of code and what it is doing.
#
# Submit your report for instructor review.
#
# You can refer to [keras documentation](https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html) for more
#
# #### Run inference (sampling)
#
# 1. encode input and retrieve initial decoder state
# 2. run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token.
# 3. Repeat with the current target token and current states

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s") #reading saved model

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %% [markdown]
# You can now generate decoded sentences as such:

# %%
for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Va !
#
# -
# Input sentence: Go.
# Decoded sentence: Va !
#
# -
# Input sentence: Go.
# Decoded sentence: Va !
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
